# %% [markdown]
# <a href="https://colab.research.google.com/github/kh408623-art/1MIS2800/blob/main/Hamparian_IC3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('SuperBowl_Finance.db')
print("SuperBowl_Finance database created")
# Out:
# SuperBowl_Finance database created

# %%
# %sql sqlite:///SuperBowl_Finance.db

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS stock_performance (
#     ticker TEXT,
#     price_before_game REAL,
#     price_week_after_game REAL,
#     trading_volume_millions INTEGER
# ) STRICT;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# []

# %%
# %%sql
# insert into stock_performance (ticker, price_before_game, price_week_after_game, trading_volume_millions)
# values
#  ('PEP',168.50, 172.10, 45),
#  ('GOOGL', 142.80, 145.20, 110),
#  ('AMZN', 170.20, 178.45, 95),
#  ('VZ', 40.10, 39.85, 60),
#  ('TSLA', 190.00, 185.20, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.40, 23.10, 15);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# 7 rows affected.
# []

# %%
# %%sql
# create table ad_buys (
#     ticker TEXT PRIMARY KEY,
#     compnay_name TEXT,
#     ad_costs_millions REAL,
#     airtime_second INTEGER
# ) STRICT;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# (sqlite3.OperationalError) table ad_buys already exists
# [SQL: create table ad_buys (
#     ticker TEXT PRIMARY KEY,
#     compnay_name TEXT,
#     ad_costs_millions REAL,
#     airtime_second INTEGER
# ) STRICT;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# insert into ad_buys (ticker, compnay_name, ad_costs_millions, airtime_second)
# values
#   ('PEP', 'PepsiCo', 7.0, 30),
#   ('GOOGL', 'Alphabet (Google)', 14.0, 60),
#   ('AMZN', 'Amazon', 14.0, 60),
#   ('VZ', 'Verizon', 7.0, 30),
#   ('TSLA', 'Tesla', 0.0, 0), -- Tesla doesn't buy ads
#   ('TMUS', 'Tmobile', 10.0, 30),
#   ('STLA', 'Stellantis (Jeep)', 6.5, 30);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# 7 rows affected.
# []

# %%
# %%sql
# Select * from stock_performance
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15)]

# %%
#Block 6
# # Instructions: Show the ticker and price before the game
# sort by ticker in alphabetical order from the stock_performance table
# %%sql
select ticker, price_before_game
from stock_performance
order by ticker asc
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('AMZN', 170.2),
#  ('GOOGL', 142.8),
#  ('PEP', 168.5),
#  ('STLA', 22.4),
#  ('TMUS', 197.68),
#  ('TSLA', 190.0),
#  ('VZ', 40.1)]

# %%
#Block 7
# # Instructions: Show all the columns for the brands that have a ticker
# beginning with the letter T in the stock_performance table

# %%sql
select *
from stock_performance
where ticker like 'T%'
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TSLA', 190.0, 185.2, 150), ('TMUS', 197.68, 199.34, 100)]

# %%
#Block 8
# # Instructions: Show only the ticker and price_after_game
# from the stock_performance table if the price is above 150

# %%sql
select ticker, price_week_after_game
from stock_performance
where price_week_after_game > 150
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 172.1), ('AMZN', 178.45), ('TSLA', 185.2), ('TMUS', 199.34)]

# %%
# %%sql
# select * from ad_buys
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 'PepsiCo', 7.0, 30),
#  ('GOOGL', 'Alphabet (Google)', 14.0, 60),
#  ('AMZN', 'Amazon', 14.0, 60),
#  ('VZ', 'Verizon', 7.0, 30),
#  ('TSLA', 'Tesla', 0.0, 0),
#  ('TMUS', 'Tmobile', 10.0, 30),
#  ('STLA', 'Stellantis (Jeep)', 6.5, 30)]

# %%
#Block 10
# # Instructions: Show the ticker and company_name from the ad_buys table in
# sort in descending order by company_name
# %%sql
select ticker, compnay_name
from ad_buys
order by compnay_name desc
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('VZ', 'Verizon'),
#  ('TMUS', 'Tmobile'),
#  ('TSLA', 'Tesla'),
#  ('STLA', 'Stellantis (Jeep)'),
#  ('PEP', 'PepsiCo'),
#  ('AMZN', 'Amazon'),
#  ('GOOGL', 'Alphabet (Google)')]

# %%
#Block 11
# # Instructions: Show the ticker and airtime seconds from the ad_buys table
# Filter to show only if the ticker begins with T and and airtime seconds is 0

# %%sql
select * from ad_buys
where ticker like 'T%' and airtime_second = 0
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TSLA', 'Tesla', 0.0, 0)]
